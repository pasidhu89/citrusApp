# %% [markdown]
# <a href="https://colab.research.google.com/github/pasidhu89/citrusApp/blob/leaves_model/leavesModle.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !nvidia-smi
# Out:
# Mon Oct 30 16:31:44 2023
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 525.105.17   Driver Version: 525.105.17   CUDA Version: 12.0     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla T4            Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   56C    P8    11W /  70W |      0MiB / 15360MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# ...

# %%
# !pip install ultralytics
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 644.8/644.8 kB 13.7 MB/s eta 0:00:00
# ...

# %%
from ultralytics import YOLO
import os
from IPython.display import display, Image
from IPython import display
display.clear_output()
# !yolo checks
# Out:
# Ultralytics YOLOv8.0.203 🚀 Python-3.10.12 torch-2.1.0+cu118 CUDA:0 (Tesla T4, 15102MiB)
# Setup complete ✅ (2 CPUs, 12.7 GB RAM, 27.1/78.2 GB disk)
#
# OS                  Linux-5.15.120+-x86_64-with-glibc2.35
# Environment         Colab
# Python              3.10.12
# Install             pip
# RAM                 12.68 GB
# CPU                 Intel Xeon 2.20GHz
# CUDA                11.8
#
# matplotlib          ✅ 3.7.1>=3.3.0
# numpy               ✅ 1.23.5>=1.22.2
# opencv-python       ✅ 4.8.0.76>=4.6.0
# pillow              ✅ 9.4.0>=7.1.2
# pyyaml              ✅ 6.0.1>=5.3.1
# requests            ✅ 2.31.0>=2.23.0
# scipy               ✅ 1.11.3>=1.4.1
# torch               ✅ 2.1.0+cu118>=1.8.0
# torchvision         ✅ 0.16.0+cu118>=0.9.0
# tqdm                ✅ 4.66.1>=4.64.0
# pandas              ✅ 1.5.3>=1.1.4
# seaborn             ✅ 0.12.2>=0.11.0
# psutil              ✅ 5.9.5
# py-cpuinfo          ✅ 9.0.0
# thop                ✅ 0.1.1-2209072238>=0.1.1

# %%
# !pip install roboflow

from roboflow import Roboflow
rf = Roboflow(api_key="tpbhPoqcBube0FkXP0ci")
project = rf.workspace("thilanka").project("blackspot-minus_k")
dataset = project.version(3).download("yolov8")
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.8/58.8 kB 1.8 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 155.3/155.3 kB 6.0 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 178.7/178.7 kB 7.6 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.8/58.8 kB 7.2 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 49.1/49.1 MB 16.4 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 67.8/67.8 kB 6.8 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 72.2/72.2 kB 8.8 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 54.5/54.5 kB 7.4 MB/s eta 0:00:00
# ...
#   Attempting uninstall: pyparsing
#     Found existing installation: pyparsing 3.1.1
#     Uninstalling pyparsing-3.1.1:
#       Successfully uninstalled pyparsing-3.1.1
#   Attempting uninstall: opencv-python-headless
#     Found existing installation: opencv-python-headless 4.8.1.78
# ...

# %%
# !yolo task=detect mode=train model=yolov8m.pt data=/content/blackspot_minus_K/data.yaml epochs=20 imgsz=640
# Out:
# Ultralytics YOLOv8.0.203 🚀 Python-3.10.12 torch-2.1.0+cu118 CUDA:0 (Tesla T4, 15102MiB)
# ...

# %%
Image(filename=f'/content/runs/detect/train5/confusion_matrix.png', width = 600)

# %%
Image(filename=f'/content/runs/detect/train5/results.png', width = 600)

# %%
# !yolo task=detect mode=val model=/content/runs/detect/train5/weights/best.pt data=/content/blackspot_minus_K/data.yaml
# Out:
# Ultralytics YOLOv8.0.203 🚀 Python-3.10.12 torch-2.1.0+cu118 CUDA:0 (Tesla T4, 15102MiB)
# Model summary (fused): 218 layers, 25840918 parameters, 0 gradients, 78.7 GFLOPs
# val: Scanning /content/blackspot_minus_K/valid/labels.cache... 98 images, 1 backgrounds, 0 corrupt: 100% 98/98 [00:00<?, ?it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 7/7 [00:04<00:00,  1.40it/s]
#                    all         98        128      0.919      0.781      0.849      0.696
#         leaf_blackspot         98         78       0.85      0.782      0.829      0.535
#                minus-k         98         50      0.987       0.78      0.868      0.857
# Speed: 2.7ms preprocess, 28.4ms inference, 0.0ms loss, 3.9ms postprocess per image
# Results saved to runs/detect/val
# 💡 Learn more at https://docs.ultralytics.com/modes/val

# %%
# !yolo task=detect mode=predict model=/content/runs/detect/train5/weights/best.pt conf=0.25 source=/content/blackspot_minus_K/test/images save=True
# Out:
# Ultralytics YOLOv8.0.203 🚀 Python-3.10.12 torch-2.1.0+cu118 CUDA:0 (Tesla T4, 15102MiB)
# Model summary (fused): 218 layers, 25840918 parameters, 0 gradients, 78.7 GFLOPs
#
# image 1/93 /content/blackspot_minus_K/test/images/105_jpeg.rf.625421a2f8e2d412c47382d7ee566d34.jpg: 640x640 2 leaf_blackspots, 36.9ms
# image 2/93 /content/blackspot_minus_K/test/images/106_jpeg.rf.c92d25ca7a7473b35d9c6952788cc0b0.jpg: 640x640 1 leaf_blackspot, 37.1ms
# image 3/93 /content/blackspot_minus_K/test/images/107_jpeg.rf.d463e4e7211e764319240949ec8b7e00.jpg: 640x640 2 leaf_blackspots, 35.8ms
# image 4/93 /content/blackspot_minus_K/test/images/120_jpeg.rf.d89dc6c75c24b70e07d2e457ec7fdddc.jpg: 640x640 4 leaf_blackspots, 28.5ms
# image 5/93 /content/blackspot_minus_K/test/images/128_jpeg.rf.cf167c2623e3d02535a54aadca1f0683.jpg: 640x640 1 leaf_blackspot, 28.5ms
# image 6/93 /content/blackspot_minus_K/test/images/163_jpeg.rf.6ee0ff04314aaaa859214b418e336e04.jpg: 640x640 1 leaf_blackspot, 28.5ms
# ...

# %%
import glob
from IPython.display import Image, display

for image_path in glob.glob(f'/content/runs/detect/predict/*.jpg')[:13]:
      display(Image(filename=image_path, width=600))
      print("\n")
