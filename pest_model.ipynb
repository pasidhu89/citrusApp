# %% [markdown]
# <a href="https://colab.research.google.com/github/pasidhu89/citrusApp/blob/pest_model/pest_model.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !nvidia-smi
# Out:
# Tue Oct 24 06:06:53 2023
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 525.105.17   Driver Version: 525.105.17   CUDA Version: 12.0     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla T4            Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   68C    P8    10W /  70W |      0MiB / 15360MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# ...

# %%
# !pip install ultralytics
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 644.5/644.5 kB 11.4 MB/s eta 0:00:00
# ...

# %%
from ultralytics import YOLO
import os
from IPython.display import display, Image
from IPython import display
display.clear_output()
# !yolo checks
# Out:
# Ultralytics YOLOv8.0.200 🚀 Python-3.10.12 torch-2.1.0+cu118 CUDA:0 (Tesla T4, 15102MiB)
# Setup complete ✅ (2 CPUs, 12.7 GB RAM, 27.1/78.2 GB disk)
#
# OS                  Linux-5.15.120+-x86_64-with-glibc2.35
# Environment         Colab
# Python              3.10.12
# Install             pip
# RAM                 12.68 GB
# CPU                 Intel Xeon 2.00GHz
# CUDA                11.8
#
# matplotlib          ✅ 3.7.1>=3.3.0
# numpy               ✅ 1.23.5>=1.22.2
# opencv-python       ✅ 4.8.0.76>=4.6.0
# pillow              ✅ 9.4.0>=7.1.2
# pyyaml              ✅ 6.0.1>=5.3.1
# requests            ✅ 2.31.0>=2.23.0
# scipy               ✅ 1.11.3>=1.4.1
# torch               ✅ 2.1.0+cu118>=1.8.0
# torchvision         ✅ 0.16.0+cu118>=0.9.0
# tqdm                ✅ 4.66.1>=4.64.0
# pandas              ✅ 1.5.3>=1.1.4
# seaborn             ✅ 0.12.2>=0.11.0
# psutil              ✅ 5.9.5
# py-cpuinfo          ✅ 9.0.0
# thop                ✅ 0.1.1-2209072238>=0.1.1

# %%
# !pip install roboflow

# from roboflow import Roboflow
# rf = Roboflow(api_key="IAe1VPxlEgaRvw3mC9Pj")
# project = rf.workspace("sri-lanka-institute-of-information-technology-ls0bn").project("lemon-butterfly")
# dataset = project.version(2).download("yolov8")


#Get Data from Google Drive links. Id is extracted form the share link. The link is shared with anyone
#replace id =

# !wget "https://docs.google.com/uc?export=download&confirm=t&id=1cK_3H_mfh8Yitn0i3n8EISnmUt58UxnW" -O butterfly.zip
# !unzip butterfly.zip -d /content/lemon_butterfly
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.8/58.8 kB 1.7 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 155.3/155.3 kB 7.5 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 178.7/178.7 kB 18.6 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.8/58.8 kB 9.3 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 49.1/49.1 MB 16.6 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 67.8/67.8 kB 9.6 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 72.2/72.2 kB 10.3 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 54.5/54.5 kB 8.2 MB/s eta 0:00:00
# ...
#   Attempting uninstall: pyparsing
#     Found existing installation: pyparsing 3.1.1
#     Uninstalling pyparsing-3.1.1:
#       Successfully uninstalled pyparsing-3.1.1
#   Attempting uninstall: opencv-python-headless
#     Found existing installation: opencv-python-headless 4.8.1.78
# ...

# %%
# [1] data.yaml file fix
# test: ../test/images
# train: lemon-butterfly-2/train/images
# val: lemon-butterfly-2/valid/images
# [2] set path to yaml file

# !yolo task=detect mode=train model=yolov8m.pt data=/content/lemon_butterfly/data.yaml epochs=20 imgsz=640
# Out:
# Ultralytics YOLOv8.0.200 🚀 Python-3.10.12 torch-2.1.0+cu118 CUDA:0 (Tesla T4, 15102MiB)
# ...

# %%
Image(filename=f'/content/citrusApp/runs/detect/train/confusion_matrix.png', width = 600)

# %%
Image(filename=f'/content/citrusApp/runs/detect/train/results.png', width = 600)

# %%
# !yolo task=detect mode=val model=/content/citrusApp/runs/detect/train2/weights/best.pt data=/content/lemon_butterfly/data.yaml
# Out:
# Ultralytics YOLOv8.0.200 🚀 Python-3.10.12 torch-2.1.0+cu118 CUDA:0 (Tesla T4, 15102MiB)
# Model summary (fused): 218 layers, 25840339 parameters, 0 gradients, 78.7 GFLOPs
# val: Scanning /content/lemon_butterfly/valid/labels.cache... 54 images, 0 backgrounds, 0 corrupt: 100% 54/54 [00:00<?, ?it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 4/4 [00:03<00:00,  1.12it/s]
#                    all         54         60      0.998        0.9      0.928      0.784
# Speed: 4.9ms preprocess, 36.3ms inference, 0.0ms loss, 4.1ms postprocess per image
# Results saved to runs/detect/val6
# 💡 Learn more at https://docs.ultralytics.com/modes/val

# %%
# !yolo task=detect mode=predict model=/content/citrusApp/runs/detect/train2/weights/best.pt conf=0.25 source=/content/lemon_butterfly/test/images save=True
# Out:
# Ultralytics YOLOv8.0.200 🚀 Python-3.10.12 torch-2.1.0+cu118 CUDA:0 (Tesla T4, 15102MiB)
# Model summary (fused): 218 layers, 25840339 parameters, 0 gradients, 78.7 GFLOPs
#
# image 1/30 /content/lemon_butterfly/test/images/1245_jpeg.rf.bd586e82529ba39677a9b2e74a13901c.jpg: 640x640 1 lemon-butterfly, 36.2ms
# image 2/30 /content/lemon_butterfly/test/images/164_jpeg.rf.bae6e0a04c852c85d59acef9a4096a08.jpg: 640x640 1 lemon-butterfly, 36.2ms
# image 3/30 /content/lemon_butterfly/test/images/180_jpeg.rf.78cc95089cc884b610e104fd6414a240.jpg: 640x640 1 lemon-butterfly, 36.1ms
# image 4/30 /content/lemon_butterfly/test/images/202_jpeg.rf.0810403a72706e01c1262bdab4647492.jpg: 640x640 1 lemon-butterfly, 27.7ms
# image 5/30 /content/lemon_butterfly/test/images/217_jpeg.rf.5e2fbb8b53c326dfc79b50813ff1fb86.jpg: 640x640 1 lemon-butterfly, 27.7ms
# image 6/30 /content/lemon_butterfly/test/images/244_jpeg.rf.59cb37121f77009fbee2ca03ef4f25e0.jpg: 640x640 1 lemon-butterfly, 27.4ms
# ...

# %%
import glob
from IPython.display import Image, display

for image_path in glob.glob(f'/content/citrusApp/runs/detect/predict/*.jpg')[:13]:
      display(Image(filename=image_path, width=600))
      print("\n")
